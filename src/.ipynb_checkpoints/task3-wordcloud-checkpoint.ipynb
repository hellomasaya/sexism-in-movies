# %%
import pandas as pd
import os
from progressbar import ProgressBar
import numpy as np
import re

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
stopwords = set(STOPWORDS)

# %%
def getData(file):
    data = pd.read_csv("../data/extracted/"+file,delimiter=',')
    moviename = ' '.join(file[:-4].split('_'))
#     print(moviename)
    return data, moviename

# %%
def convertToModelInputFormat(data):
    ans = []
    speakers = list(set(list(data['Speaker'])))
    for speaker in speakers:
        dialogues = data[data['Speaker']==speaker]
        dialogues = list(dialogues['Dialogue'])
        temp = []
        temp.append(speaker)
        temp.append(dialogues)
        ans.append(temp)
    return ans

# %%
def getTrueLabels(df, moviename):
    labelsfile = pd.read_csv('../data/Pre-processing_files/polygraph_matched_scriptid_title_gender.txt', 
                         delimiter='\t', names=['Match', 'Movie', 'Code', 'Character', 'Gender'])
    labelsfile = labelsfile[labelsfile['Match']=='Matched']

    movie = labelsfile[labelsfile['Movie']==moviename]
    if movie is not None:
        movie = movie[['Character', 'Gender']]
        movie['Character'] = movie['Character']
        temp = list(df['Speaker'])
        gen = []
#         print(temp, movie['Character'])
        count = 0
        for speaker in temp:
            try:
                gender = movie[movie['Character'].str.contains(speaker)]
                gender = list(gender['Gender'])
                gen.append(gender[0])
            except:
                gen.append(np.nan)
        df['Gender'] = gen
    return df

# %%
entire_data = pd.DataFrame([['Speaker', ['d1']]], columns=['Speaker', 'Dialogues'])
files = os.listdir('../data/extracted')
files.sort()
pbar = ProgressBar()
for file in pbar(files):
    if file[-4:] != ".csv":
        continue
    else:
        data, moviename = getData(file)
        ans = convertToModelInputFormat(data)
        df = pd.DataFrame(ans, columns = ['Speaker', 'Dialogues'])
        df = getTrueLabels(df, moviename)
        df['Movie'] = moviename
        entire_data = entire_data.append(df, ignore_index=True)

entire_data = entire_data.drop(0)
entire_data.head()
# Out:
# 100% |########################################################################|
#     Speaker                                          Dialogues Gender  \
# 1   patrick  [I missed you., It was a bratwurst.  I was eat...      m
# 2  mandelia                 [The whole folio.  All the plays.]    NaN
# 3  mandella  [Uh, yeah, I read it all, Haven't you?, Who's ...      f
# 4     rider                                    [Hey -- sorry.]    NaN
# 5    trevor  [You're a freedom fighter. Be proud, sister., ...    NaN
#
#                         Movie
# 1  10 Things I Hate About You
# 2  10 Things I Hate About You
# 3  10 Things I Hate About You
# 4  10 Things I Hate About You
# 5  10 Things I Hate About You

# %%
entire_data.shape
# Out:
# (42843, 4)

# %%
male = entire_data[entire_data['Gender'] == 'm']
male.shape
# Out:
# (4754, 4)

# %%
female = entire_data[entire_data['Gender'] == 'f']
female.shape
# Out:
# (2173, 4)

# %%
def getCloud(freq):
    wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='white',
                    stopwords = stopwords,
                    min_font_size = 10, max_words=1000).generate_from_frequencies(freq)
    plt.figure(figsize = (5, 5), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()

# %%
def getWordCloud(data):
    freq = {}
    comment_words = ''
    alldialogues = data['Dialogues'].tolist()
    pbar = ProgressBar()
    for dialogues in pbar(alldialogues):
        for dialogue in dialogues:
            dialogue = str(dialogue).lower()
            doc = nlp(dialogue)
            for token in doc:
                if (token.lemma_=="-PRON-" or token.pos_=="PRON") or (token.pos_=="NUM" or token.pos_=="PUNCT")  or token.pos_=="PART":
                    continue
                elif re.match("a|the|an|the|to|in|for|of|or|by|with|is|on|that|be", token.text):
                    continue
                elif token.lemma_ in freq:
                    freq[token.lemma_]+=1
                else:
                    freq[token.lemma_] = 1
                comment_words += token.lemma_
#     print(freq)
    return freq

# %%
freq = getWordCloud(female)
# Out:
# 100% |########################################################################|
# {'uh': 621, 'yeah': 2315, 'read': 415, 'have': 15132, 'not': 26825, 'be': 45501, 'pat': 28, 'verona': 8, 'go': 10063, 'year': 1159, 'hear': 1243, 'do': 25032, 'porn': 11, 'movie': 292, 'look': 4053, 'so': 5682, 'just': 6471, 'little': 1572, 'slit': 6, 'but': 6106, 'imagine': 132, 'thing': 2206, 'would': 4519, 'say': 4334, 'during': 72, 'sex': 250, 'tragic': 11, 'could': 2344, ' ': 30218, 'sure': 1312, 'william': 80, 'some': 2071, 'friend': 871, 'charming': 41, 'new': 731, 'development': 11, 'never': 1889, 'state': 144, 'school': 553, 'prove': 91, 'matter': 423, 'janice': 4, 'parker': 30, 'roadie': 2, 'marilyn': 50, 'manson': 4, 'really': 2280, 'easy': 285, 'people': 1411, 'white': 296, 'suburban': 5, 'high': 262, 'boy': 644, 'smoke': 136, 'much': 1299, 'hemp': 1, 'free': 202, 'trevor': 13, 'can': 6810, "importun'd": 1, 'love': 2118, 'honourable': 1, 'fashion': 26, 'wish': 330, 'here': 4448, 'witness': 66, 'rebirth': 1, 'punk': 10, 'rock': 96, 'party': 317, 'think': 5378, 'oppose': 12, 'social': 34, 'choice': 143, 'where': 2190, 'kat': 13, 'guess': 640, 'refrain': 1, 'heart': 312, 'courage': 24, 'make': 2920, 'know': 8450, 'well': 3139, 'since': 385, 'date': 258, 'see': 4113, 'meet': 798, 'remember': 705, 'word': 424, 'shakespeare': 15, 'right': 3153, 'now': 3282, 'weird': 222, 'change': 450, 'hair': 293, 'may': 1007, 'wanna': 374, 'nowhere': 40, 'hi': 760, 'daddy': 410, 'even': 1218, 'question': 333, 'want': 5002, 'stay': 791, 'get': 9179, 'upset': 104, 'this': 8409, 'if': 4142, 'start': 1012, 'fair': 118, 'mutant': 4, 'quick': 107, 'roxanne': 26, 'korrine': 1, 'barrett': 1, 'horrendous': 1, 'public': 54, 'break-': 1, 'quad': 3, 'hacking': 1, 'gagging': 1, 'spitting': 2, 'part': 375, 'please': 1458, 'cute': 147, 'name': 797, 'no': 7019, 'fault': 167, 'proper': 38, 'cameron': 7, 'mercy': 29, 'particularly': 11, 'hideous': 14, 'breed': 7, 'loser': 52, 'sister': 358, 'until': 341, 'unsolved': 2, 'mystery': 26, 'use': 869, 'popular': 38, 'when': 2576, 'like': 5766, 'sick': 277, 'something': 2146, 'gosh': 38, 'find': 1419, 'boyfriend': 137, "c'esc": 1, 'ma': 44, 'tete': 1, 'head': 775, 'how': 3694, 'though': 255, 'useful': 15, 'good': 2441, 'store': 95, 'champagne': 26, 'cost': 76, 'stuff': 427, 'chat': 31, 'life': 1145, 'point': 328, 'someone': 720, 'french': 63, 'wench': 5, 'plan': 267, 'progress': 21, 'show': 726, 'give': 1702, 'sign': 248, 'walk': 654, 'god': 1609, 'repulsive': 8, 'perfect': 195, 'ever': 1098, 'consider': 122, 'mean': 2153, 'seriously': 123, 'potential': 19, 'bury': 51, 'under': 260, 'hostility': 8, 'least': 271, 'wear': 326, 'bra': 15, 'copine': 1, 'count': 105, 'promise': 380, 'keep': 1004, 'help': 1201, 'cause': 250, 'thug': 6, 'obviously': 74, 'fail': 55, 'sweet': 227, 'eber': 1, 'deep': 122, 'conditioner': 5, 'every': 587, 'day': 1305, 'blowdryer': 1, 'diffuser': 1, 'shirt': 95, 'expensive': 30, 'hopefully': 15, 'bogey': 4, 'lowenstein': 3, 'unless': 129, 'lesbian': 12, 'picture': 265, 'jar': 11, 'leto': 7, 'drawer': 33, 'pretty': 442, 'harbor': 18, 'same': 484, 'tendency': 6, 'dip': 16, 'guy': 1325, 'turn': 950, 'scream': 111, 'menstrual': 2, 'bitch': 216, 'try': 1483, 'study': 114, 'tell': 2563, 'night': 1163, 'less': 116, 'oh': 4129, 'my': 514, 'normal': 99, 'why': 3004, 'bother': 124, 'saturday': 56, 'freak': 121, 'suck': 101, 'must': 812, 'small': 176, 'group': 98, 'gloria': 2, 'steinem': 1, 'over': 1185, 'expect': 213, 'ruin': 93, 'will': 7509, 'busy': 122, 'listening': 3, 'need': 1837, 'prozac': 3, 'completely': 147, 'wretched': 13, 'suppose': 519, 'mandella': 2, 'out': 1777, 'should': 1654, 'obsess': 25, 'dead': 540, 'unbalanced': 2, 'joey': 16, 'chastity': 3, 'mind': 541, 'drink': 443, 'surprise': 124, 'queen': 77, 'harry': 255, 'neat': 15, 'back': 2546, 'practically': 25, 'propose': 41, 'dermatologist': 1, 'dr': 246, 'bonchowski': 1, 'great': 969, 'exactly': 275, 'relevant': 9, 'conversation': 75, 'combination': 6, 'different': 274, 'more': 1495, 'gentleman': 96, 'sometimes': 330, 'wonder': 254,  ...

# %%
getCloud(freq)

# %%
freq2 = getWordCloud(male)
# Out:
#  40% |#############################                                           |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-36bb1a012c0c> in <module>
# ----> 1 freq2 = getWordCloud(male)
#
# <ipython-input-12-2d51d2a479e4> in getWordCloud(data)
#       7         for dialogue in dialogues:
#       8             dialogue = str(dialogue).lower()
# ----> 9             doc = nlp(dialogue)
#      10             for token in doc:
#      11                 if (token.lemma_=="-PRON-" or token.pos_=="PRON") or (token.pos_=="NUM" or token.pos_=="PUNCT")  or token.pos_=="PART":
#
# /usr/local/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     388             if not hasattr(proc, "__call__"):
#     389                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 390             doc = proc(doc, **component_cfg.get(name, {}))
#     391             if doc is None:
#     392                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     163             Must match expected shape
#     164         """
# --> 165         return self.predict(x)
#     166
#     167     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     163             Must match expected shape
#     164         """
# --> 165         return self.predict(x)
#     166
#     167     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.7/site-packages/thinc/api.py in predict(seqs_in)
#     277     def predict(seqs_in):
#     278         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 279         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     280         return layer.ops.unflatten(X, lengths, pad=pad)
#     281
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     163             Must match expected shape
#     164         """
# --> 165         return self.predict(x)
#     166
#     167     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/resnet.py in __call__(self, X)
#      12
#      13     def __call__(self, X):
# ---> 14         Y = self._layers[0](X)
#      15         if isinstance(X, list) or isinstance(X, tuple):
#      16             return [X[i] + Y[i] for i in range(len(X))]
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     163             Must match expected shape
#     164         """
# --> 165         return self.predict(x)
#     166
#     167     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     163             Must match expected shape
#     164         """
# --> 165         return self.predict(x)
#     166
#     167     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/layernorm.py in predict(self, X)
#      46
#      47     def predict(self, X):
# ---> 48         X = self.child.predict(X)
#      49         N, mu, var = _get_moments(self.ops, X)
#      50         Xh = _forward(self.ops, X, mu, var)
#
# /usr/local/lib/python3.7/site-packages/thinc/neural/_classes/maxout.py in predict(self, X__BI)
#      64     def predict(self, X__BI):
#      65         W = self.W.reshape((self.nO * self.nP, self.nI))
# ---> 66         X__BOP = self.ops.gemm(X__BI, W, trans2=True)
#      67         X__BOP += self.b.reshape((self.nO * self.nP,))
#      68         X__BOP = X__BOP.reshape((X__BOP.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
getCloud(freq2)
