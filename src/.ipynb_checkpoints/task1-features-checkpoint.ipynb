# %%
import pandas as pd
import os
from progressbar import ProgressBar
import numpy as np
import numpy as np
import re
import math
import spacy
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction import text
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %% [markdown]
# # 1. Preparing Data

# %%
def getData(file):
    data = pd.read_csv("../data/extracted/"+file,delimiter=',')
    moviename = ' '.join(file[:-4].split('_'))
#     print(moviename)
    return data, moviename

# %%
def getTrueLabels(df, moviename, labelsfile):

    
    movie = labelsfile[labelsfile['Movie']==moviename]
    if movie is not None:
        movie = movie[['Speaker', 'Gender']]
        movie['Speaker'] = movie['Speaker']
        temp = list(df['Speaker'])
        gen = []
#         print(temp, movie['Character'])
        count = 0
        for speaker in temp:
            try:
                gender = movie[movie['Speaker'].str.contains(speaker)]
                gender = list(gender['Gender'])
                gen.append(gender[0])
            except:
                gen.append(np.nan)
        df['Gender'] = gen
    return df

# %%
def convertToModelInputFormat(data):
    ans = []
    speakers = list(set(list(data['Speaker'])))
    for speaker in speakers:
        dialogues = data[data['Speaker']==speaker]
        dialogues = list(dialogues['Dialogue'])
        temp = []
        speaker = str(speaker)
        speaker = speaker.replace(".", "")
        speaker = speaker.replace("\"", "")
        speaker = speaker.replace("\t", "")
        temp.append(speaker)
        temp.append(dialogues)
        ans.append(temp)
    return ans

# %%
def test_train_split(entire_data):
    data = entire_data.copy()
    train_set = data.sample(frac=0.70, random_state=0)
    test_set = data.drop(train_set.index)
    train_set_labels = train_set.pop('Gender')
    test_set_labels = test_set.pop('Gender')
    return train_set, train_set_labels, test_set, test_set_labels

# %%
labelsfile = pd.read_csv('../data/Pre-processing_files/polygraph_matched_scriptid_title_gender.txt', 
                     delimiter='\t', names=['Match', 'Movie', 'Code', 'Speaker', 'Gender'])
labelsfile = labelsfile[labelsfile['Match']=='Matched']
labelsfile = labelsfile[['Movie', 'Speaker','Gender']]
labelsfile2 = pd.read_csv("../data/task1/entire_data2.csv",delimiter=',')
labelsfile = labelsfile.append(labelsfile2, ignore_index=True)

# %%
entire_data = pd.DataFrame([['Speaker', ['d1']]], columns=['Speaker', 'Dialogues'])
files = os.listdir('../data/extracted')
files.sort()
pbar = ProgressBar()
for file in pbar(files):
    if file[-4:] != ".csv":
        continue
    else:
        data, moviename = getData(file)
        ans = convertToModelInputFormat(data)
        df = pd.DataFrame(ans, columns = ['Speaker', 'Dialogues'])
        df = getTrueLabels(df, moviename, labelsfile)
        df['Movie'] = moviename
        entire_data = entire_data.append(df, ignore_index=True)

entire_data = entire_data.drop(0)
entire_data
# Out:
# 100% |########################################################################|
#            Speaker                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...       f
# 4           bianca  [Did you change your hair?, You might wanna th...       f
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...       m
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...       m
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie
# 1      10 Things I Hate About You
# 2      10 Things I Hate About You
# 3      10 Things I Hate About You
# 4      10 Things I Hate About You
# 5      10 Things I Hate About You
# ...                           ...
# 42839                         xXx
# 42840                         xXx
# 42841                         xXx
# 42842                         xXx
# 42843                         xXx
#
# [42843 rows x 4 columns]

# %%
null_url = pd.isnull(entire_data['Gender'])
temp = entire_data[null_url]

# %%
temp
# Out:
#                         Speaker  \
# 583      white - march 14, 2012
# 844                         nan
# 845                billy's face
# 846                 black dildo
# 847                         lek
# ...                         ...
# 39676                 mrs floyd
# 39682                  mr goudy
# 40165  octobereighthninety-nine
# 40745             july 27, 2000
# 41972                         *
#
#                                                Dialogues Gender  \
# 583    [Blue Revised - April 7, 2012 Pink Revised - A...    NaN
# 844                                                   []    NaN
# 845    [plunges into water, FULL FRAME. Bubbles spira...    NaN
# 846    [Free to all. Help get prisoners clean., Come ...    NaN
# 847            [Do you have father?, He come visit you?]    NaN
# ...                                                  ...    ...
# 39676  [Frank Ross's daughter. My poor child. My poor...    NaN
# 39682  [Objection. Hearsay., Let us restrict it to "k...    NaN
# 40165                     [written by m.night.shyamalan]    NaN
# 40745  [WARNER BROS.                                 ...    NaN
# 41972  [GIRL * Where were you?, GUY * I was looking f...    NaN
#
#                       Movie
# 583                      42
# 844    A Prayer Before Dawn
# 845    A Prayer Before Dawn
# 846    A Prayer Before Dawn
# 847    A Prayer Before Dawn
# ...                     ...
# 39676             True Grit
# 39682             True Grit
# 40165           Unbreakable
# 40745      Walk to Remember
# 41972            Wind Chill
#
# [713 rows x 4 columns]

# %%
entire_data.loc[entire_data['Speaker'] == '', 'Speaker'] = np.nan

# %%
# final_data = entire_data[entire_data.apply(lambda x: x.values.tolist() not in temp.values.tolist(), axis=1)]

# %%
entire_data.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=None,
    inplace=True
)

# %% [markdown]
# # 2. Making features

# %%
final_data = entire_data.rename(columns={"Speaker": "Name"})

# %%
final_data.loc[final_data['Gender'] == '?', 'Gender'] = "male"

# %%
# err

# %%
final_data.loc[final_data['Gender'] == "m", 'Gender'] = "male"
final_data.loc[final_data['Gender'] == "f", 'Gender'] = "female"
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie
# 1      10 Things I Hate About You
# 2      10 Things I Hate About You
# 3      10 Things I Hate About You
# 4      10 Things I Hate About You
# 5      10 Things I Hate About You
# ...                           ...
# 42839                         xXx
# 42840                         xXx
# 42841                         xXx
# 42842                         xXx
# 42843                         xXx
#
# [42126 rows x 4 columns]

# %%
def numberOfMF(data):
    df = data.groupby('Gender')['Name'].count()
    print(df)
    df = pd.DataFrame({'Names': [df[0], df[1]]}, index=['Female', 'Male'])
    plot = df.plot.pie(subplots=True, figsize=(11, 6), colors = ['#ffb3e6','#c2c2f0'], 
                       autopct = "%.2f%%", labeldistance=1.15)
#   wedgeprops = {'linewidth':1.5, 'edgecolor':'white'}

# %%
numberOfMF(final_data)
# Out:
# Gender
# female    15427
# male      26699
# Name: Name, dtype: int64

# %%
def checkEnd(name):
    if name[-1] in "aeiou":
        return "vowel"
    return "consonant"

final_data["EndsWith"] = final_data["Name"].apply(checkEnd)
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith
# 1      10 Things I Hate About You  consonant
# 2      10 Things I Hate About You  consonant
# 3      10 Things I Hate About You  consonant
# 4      10 Things I Hate About You      vowel
# 5      10 Things I Hate About You  consonant
# ...                           ...        ...
# 42839                         xXx  consonant
# 42840                         xXx  consonant
# 42841                         xXx      vowel
# 42842                         xXx  consonant
# 42843                         xXx  consonant
#
# [42126 rows x 5 columns]

# %%
def letterClass(name):
    name_list = [x for x in name]
    vowel_counter = 0
    consonant_counter = 0
    for letter in name_list:
        if letter in ['a','e','i','o','u']:
            vowel_counter+=1
        else:
            consonant_counter+=1
    
    return vowel_counter, consonant_counter

final_data['VowelCount'] = final_data['Name'].apply(lambda x: letterClass(x)[0])
final_data['ConsonantCount'] = final_data['Name'].apply(lambda x: letterClass(x)[1])

final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith  VowelCount  ConsonantCount
# 1      10 Things I Hate About You  consonant           2               4
# 2      10 Things I Hate About You  consonant           1               2
# 3      10 Things I Hate About You  consonant           1               2
# 4      10 Things I Hate About You      vowel           3               3
# 5      10 Things I Hate About You  consonant           2               3
# ...                           ...        ...         ...             ...
# 42839                         xXx  consonant           2               5
# 42840                         xXx  consonant           2               5
# 42841                         xXx      vowel           2               3
# 42842                         xXx  consonant           3               8
# 42843                         xXx  consonant           1               3
#
# [42126 rows x 7 columns]

# %%
def getLength(name):
    return len(name)

final_data["Length"] = final_data["Name"].apply(getLength)

# %%
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith  VowelCount  ConsonantCount  \
# 1      10 Things I Hate About You  consonant           2               4
# 2      10 Things I Hate About You  consonant           1               2
# 3      10 Things I Hate About You  consonant           1               2
# 4      10 Things I Hate About You      vowel           3               3
# 5      10 Things I Hate About You  consonant           2               3
# ...                           ...        ...         ...             ...
# 42839                         xXx  consonant           2               5
# 42840                         xXx  consonant           2               5
# 42841                         xXx      vowel           2               3
# 42842                         xXx  consonant           3               8
# 42843                         xXx  consonant           1               3
#
#        Length
# 1           6
# 2           3
# 3           3
# 4           6
# 5           5
# ...       ...
# 42839       7
# 42840       7
# 42841       5
# 42842      11
# 42843       4
#
# [42126 rows x 8 columns]

# %%
def checkMoreVowels(data):
    data['vcCompare']= np.where(data['ConsonantCount'] == data['VowelCount'], 'equal', np.where(
    data['ConsonantCount'] > data['VowelCount'], 'moreConsonants', 'moreVowels')) 

checkMoreVowels(final_data)
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith  VowelCount  ConsonantCount  \
# 1      10 Things I Hate About You  consonant           2               4
# 2      10 Things I Hate About You  consonant           1               2
# 3      10 Things I Hate About You  consonant           1               2
# 4      10 Things I Hate About You      vowel           3               3
# 5      10 Things I Hate About You  consonant           2               3
# ...                           ...        ...         ...             ...
# 42839                         xXx  consonant           2               5
# 42840                         xXx  consonant           2               5
# 42841                         xXx      vowel           2               3
# 42842                         xXx  consonant           3               8
# 42843                         xXx  consonant           1               3
#
#        Length       vcCompare
# 1           6  moreConsonants
# 2           3  moreConsonants
# 3           3  moreConsonants
# 4           6           equal
# 5           5  moreConsonants
# ...       ...             ...
# 42839       7  moreConsonants
# 42840       7  moreConsonants
# 42841       5  moreConsonants
# 42842      11  moreConsonants
# 42843       4  moreConsonants
#
# [42126 rows x 9 columns]

# %%
def checkVCDifference(data):
    data['vcDifference']= data['ConsonantCount'] - data['VowelCount']

checkVCDifference(final_data)

# %%
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith  VowelCount  ConsonantCount  \
# 1      10 Things I Hate About You  consonant           2               4
# 2      10 Things I Hate About You  consonant           1               2
# 3      10 Things I Hate About You  consonant           1               2
# 4      10 Things I Hate About You      vowel           3               3
# 5      10 Things I Hate About You  consonant           2               3
# ...                           ...        ...         ...             ...
# 42839                         xXx  consonant           2               5
# 42840                         xXx  consonant           2               5
# 42841                         xXx      vowel           2               3
# 42842                         xXx  consonant           3               8
# 42843                         xXx  consonant           1               3
#
#        Length       vcCompare  vcDifference
# 1           6  moreConsonants             2
# 2           3  moreConsonants             1
# 3           3  moreConsonants             1
# 4           6           equal             0
# 5           5  moreConsonants             1
# ...       ...             ...           ...
# 42839       7  moreConsonants             3
# 42840       7  moreConsonants             3
# 42841       5  moreConsonants             1
# 42842      11  moreConsonants             5
# 42843       4  moreConsonants             2
#
# [42126 rows x 10 columns]

# %%
def checkVowelCount(col):
    if col > 2:
        return 'more'
    return 'less'

def checkConsonantCount(col):
    if col > 3:
        return 'more'
    return 'less'

final_data["VowelCountClass"] = final_data["VowelCount"].apply(checkVowelCount)
final_data["ConsonantCountClass"] = final_data["ConsonantCount"].apply(checkConsonantCount)

# %%
def checkMoreVowels(col):
    if col == 'moreConsonants':
        return 'less'
    return 'more'

final_data["MoreVowels"] = final_data["vcCompare"].apply(checkMoreVowels)
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith  VowelCount  ConsonantCount  \
# 1      10 Things I Hate About You  consonant           2               4
# 2      10 Things I Hate About You  consonant           1               2
# 3      10 Things I Hate About You  consonant           1               2
# 4      10 Things I Hate About You      vowel           3               3
# 5      10 Things I Hate About You  consonant           2               3
# ...                           ...        ...         ...             ...
# 42839                         xXx  consonant           2               5
# 42840                         xXx  consonant           2               5
# 42841                         xXx      vowel           2               3
# 42842                         xXx  consonant           3               8
# 42843                         xXx  consonant           1               3
#
#        Length       vcCompare  vcDifference VowelCountClass  \
# 1           6  moreConsonants             2            less
# 2           3  moreConsonants             1            less
# 3           3  moreConsonants             1            less
# 4           6           equal             0            more
# 5           5  moreConsonants             1            less
# ...       ...             ...           ...             ...
# 42839       7  moreConsonants             3            less
# 42840       7  moreConsonants             3            less
# 42841       5  moreConsonants             1            less
# 42842      11  moreConsonants             5            more
# 42843       4  moreConsonants             2            less
#
#       ConsonantCountClass MoreVowels
# 1                    more       less
# 2                    less       less
# 3                    less       less
# 4                    less       more
# 5                    less       less
# ...                   ...        ...
# 42839                more       less
# 42840                more       less
# 42841                less       less
# 42842                more       less
# 42843                less       less
#
# [42126 rows x 13 columns]

# %%
def checkMoreDifference(col):
    if col > 1:
        return 'more'
    return 'less'

final_data["MoreDifferenceClass"] = final_data["vcDifference"].apply(checkMoreDifference)
final_data
# Out:
#               Name                                          Dialogues  Gender  \
# 1           sharon  [In the microwave., What's a synonym for throb...  female
# 2              guy                                [Drink up, sister.]    male
# 3              kat  [Leave it, Why didn't we just read the Hardy B...  female
# 4           bianca  [Did you change your hair?, You might wanna th...  female
# 5            derek  [ Michael, my brother, peace, Kat, my lady, yo...    male
# ...            ...                                                ...     ...
# 42839      gibbons  [Evening, Sam., Not a whole helluva lot. His f...    male
# 42840      trucker  [I said, you got a problem, boy?, With what? I...    male
# 42841        yorgi  [This pizda? Never seen him before., Cops. Lik...    male
# 42842  nerdy agent  [This is your communicator. You'll identify yo...    male
# 42843         virg  [What's so damn funny?, Heads up, man. What's ...    male
#
#                             Movie   EndsWith  VowelCount  ConsonantCount  \
# 1      10 Things I Hate About You  consonant           2               4
# 2      10 Things I Hate About You  consonant           1               2
# 3      10 Things I Hate About You  consonant           1               2
# 4      10 Things I Hate About You      vowel           3               3
# 5      10 Things I Hate About You  consonant           2               3
# ...                           ...        ...         ...             ...
# 42839                         xXx  consonant           2               5
# 42840                         xXx  consonant           2               5
# 42841                         xXx      vowel           2               3
# 42842                         xXx  consonant           3               8
# 42843                         xXx  consonant           1               3
#
#        Length       vcCompare  vcDifference VowelCountClass  \
# 1           6  moreConsonants             2            less
# 2           3  moreConsonants             1            less
# 3           3  moreConsonants             1            less
# 4           6           equal             0            more
# 5           5  moreConsonants             1            less
# ...       ...             ...           ...             ...
# 42839       7  moreConsonants             3            less
# 42840       7  moreConsonants             3            less
# 42841       5  moreConsonants             1            less
# 42842      11  moreConsonants             5            more
# 42843       4  moreConsonants             2            less
#
#       ConsonantCountClass MoreVowels MoreDifferenceClass
# 1                    more       less                more
# 2                    less       less                less
# 3                    less       less                less
# 4                    less       more                less
# 5                    less       less                less
# ...                   ...        ...                 ...
# 42839                more       less                more
# 42840                more       less                more
# 42841                less       less                less
# 42842                more       less                more
# 42843                less       less                more
#
# [42126 rows x 14 columns]

# %%
def getASCII(name):
    asciiVal = 0
    for x in name:
        asciiVal += ord(x)-97
    return asciiVal/len(name)

final_data["ASCIIval"] = final_data["Name"].apply(getASCII)

# %%
def makeBinary(data, cols, zero, one):
    for col in cols:
        data[col] = np.where((data[col] == zero),0,data[col])        
        data[col] = np.where((data[col] == one),1,data[col])
    return data

final_data = makeBinary(final_data, ['VowelCountClass', 'MoreVowels', 'MoreDifferenceClass'], 'less', 'more')
final_data = makeBinary(final_data, ['EndsWith'], 'consonant', 'vowel')
final_data = makeBinary(final_data, ['Gender'], 'male', 'female')

# %%
def dropColumns(data, collist):
    data = data.drop(columns=collist)
    return data

final_data2 = dropColumns(final_data, ['vcCompare', 'ConsonantCountClass', 'Name', 'Movie'])

# %%
final_data2
# Out:
#                                                Dialogues Gender EndsWith  \
# 1      [In the microwave., What's a synonym for throb...      1        0
# 2                                    [Drink up, sister.]      0        0
# 3      [Leave it, Why didn't we just read the Hardy B...      1        0
# 4      [Did you change your hair?, You might wanna th...      1        1
# 5      [ Michael, my brother, peace, Kat, my lady, yo...      0        0
# ...                                                  ...    ...      ...
# 42839  [Evening, Sam., Not a whole helluva lot. His f...      0        0
# 42840  [I said, you got a problem, boy?, With what? I...      0        0
# 42841  [This pizda? Never seen him before., Cops. Lik...      0        1
# 42842  [This is your communicator. You'll identify yo...      0        0
# 42843  [What's so damn funny?, Heads up, man. What's ...      0        0
#
#        VowelCount  ConsonantCount  Length  vcDifference VowelCountClass  \
# 1               2               4       6             2               0
# 2               1               2       3             1               0
# 3               1               2       3             1               0
# 4               3               3       6             0               1
# 5               2               3       5             1               0
# ...           ...             ...     ...           ...             ...
# 42839           2               5       7             3               0
# 42840           2               5       7             3               0
# 42841           2               3       5             1               0
# 42842           3               8      11             5               1
# 42843           1               3       4             2               0
#
#       MoreVowels MoreDifferenceClass   ASCIIval
# 1              0                   1  11.500000
# 2              0                   0  16.666667
# 3              0                   0   9.666667
# 4              1                   0   4.000000
# 5              0                   0   7.600000
# ...          ...                 ...        ...
# 42839          0                   1   8.714286
# 42840          0                   1  12.714286
# 42841          0                   0  13.800000
# 42842          0                   1   3.454545
# 42843          0                   1  13.000000
#
# [42126 rows x 11 columns]

# %% [markdown]
# # 2.2 Features based on Dialogue

# %%
from textblob import TextBlob

def getPolarityAndSubjectivity(dialogue):
    p=0
    s=0
    ld= len(dialogue)
    for d in dialogue:
        p += TextBlob(d).sentiment.polarity
        s +=  TextBlob(d).sentiment.subjectivity
    return p/ld, s/ld 

final_data2['PolarityBlob'] = final_data2['Dialogues'].apply(lambda x: getPolarityAndSubjectivity(x)[0])

# %%
final_data2
# Out:
#                                                Dialogues Gender EndsWith  \
# 1      [In the microwave., What's a synonym for throb...      1        0
# 2                                    [Drink up, sister.]      0        0
# 3      [Leave it, Why didn't we just read the Hardy B...      1        0
# 4      [Did you change your hair?, You might wanna th...      1        1
# 5      [ Michael, my brother, peace, Kat, my lady, yo...      0        0
# ...                                                  ...    ...      ...
# 42839  [Evening, Sam., Not a whole helluva lot. His f...      0        0
# 42840  [I said, you got a problem, boy?, With what? I...      0        0
# 42841  [This pizda? Never seen him before., Cops. Lik...      0        1
# 42842  [This is your communicator. You'll identify yo...      0        0
# 42843  [What's so damn funny?, Heads up, man. What's ...      0        0
#
#        VowelCount  ConsonantCount  Length  vcDifference VowelCountClass  \
# 1               2               4       6             2               0
# 2               1               2       3             1               0
# 3               1               2       3             1               0
# 4               3               3       6             0               1
# 5               2               3       5             1               0
# ...           ...             ...     ...           ...             ...
# 42839           2               5       7             3               0
# 42840           2               5       7             3               0
# 42841           2               3       5             1               0
# 42842           3               8      11             5               1
# 42843           1               3       4             2               0
#
#       MoreVowels MoreDifferenceClass   ASCIIval  PolarityBlob
# 1              0                   1  11.500000      0.000000
# 2              0                   0  16.666667      0.000000
# 3              0                   0   9.666667      0.029439
# 4              1                   0   4.000000      0.036752
# 5              0                   0   7.600000      0.000000
# ...          ...                 ...        ...           ...
# 42839          0                   1   8.714286      0.059354
# 42840          0                   1  12.714286      0.060580
# 42841          0                   0  13.800000      0.055119
# 42842          0                   1   3.454545      0.000000
# 42843          0                   1  13.000000      0.105556
#
# [42126 rows x 12 columns]

# %%
final_data2['SubjectivityBlob'] = final_data2['Dialogues'].apply(lambda x: getPolarityAndSubjectivity(x)[1])

# %%
def getSentiMentfromPolarity(dial, col, pol, val):
    dial[col]=''
    dial.loc[dial[pol]>val,col]=1
    dial.loc[dial[pol]==val,col]=0
    dial.loc[dial[pol]<val,col]=-1
    return dial

final_data2 = getSentiMentfromPolarity(final_data2, 'SentiBlob', 'PolarityBlob', 0)

# %%
final_data2.to_csv('../data/task1/features-mid.csv', index=False)

# %%
final_data2
# Out:
#                                                Dialogues Gender EndsWith  \
# 1      [In the microwave., What's a synonym for throb...      1        0
# 2                                    [Drink up, sister.]      0        0
# 3      [Leave it, Why didn't we just read the Hardy B...      1        0
# 4      [Did you change your hair?, You might wanna th...      1        1
# 5      [ Michael, my brother, peace, Kat, my lady, yo...      0        0
# ...                                                  ...    ...      ...
# 42839  [Evening, Sam., Not a whole helluva lot. His f...      0        0
# 42840  [I said, you got a problem, boy?, With what? I...      0        0
# 42841  [This pizda? Never seen him before., Cops. Lik...      0        1
# 42842  [This is your communicator. You'll identify yo...      0        0
# 42843  [What's so damn funny?, Heads up, man. What's ...      0        0
#
#        VowelCount  ConsonantCount  Length  vcDifference VowelCountClass  \
# 1               2               4       6             2               0
# 2               1               2       3             1               0
# 3               1               2       3             1               0
# 4               3               3       6             0               1
# 5               2               3       5             1               0
# ...           ...             ...     ...           ...             ...
# 42839           2               5       7             3               0
# 42840           2               5       7             3               0
# 42841           2               3       5             1               0
# 42842           3               8      11             5               1
# 42843           1               3       4             2               0
#
#       MoreVowels MoreDifferenceClass   ASCIIval  PolarityBlob  \
# 1              0                   1  11.500000      0.000000
# 2              0                   0  16.666667      0.000000
# 3              0                   0   9.666667      0.029439
# 4              1                   0   4.000000      0.036752
# 5              0                   0   7.600000      0.000000
# ...          ...                 ...        ...           ...
# 42839          0                   1   8.714286      0.059354
# 42840          0                   1  12.714286      0.060580
# 42841          0                   0  13.800000      0.055119
# 42842          0                   1   3.454545      0.000000
# 42843          0                   1  13.000000      0.105556
#
#        SubjectivityBlob SentiBlob
# 1              0.000000         0
# 2              0.000000         0
# 3              0.251265         1
# 4              0.225850         1
# 5              0.333333         0
# ...                 ...       ...
# 42839          0.358953         1
# 42840          0.514921         1
# 42841          0.261689         1
# 42842          0.000000         0
# 42843          0.233333         1
#
# [42126 rows x 14 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def getPolarityVader(dialogue):
    c=0
    for d in dialogue:
        c+= analyzer.polarity_scores(dialogue)['compound']
    return c/len(dialogue)

final_data2['VADER'] = final_data2['Dialogues'].apply(getPolarityVader)

# %%
final_data2 = getSentiMentfromPolarity(final_data2, 'SentiVADER', 'VADER', 0.05)

# %%
final_data2.to_csv('../data/task1/features-mid-2.csv', index=False)
