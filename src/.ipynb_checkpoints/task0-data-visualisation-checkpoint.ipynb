# %% [markdown]
# # Data visualisation
# ## 1. By Year of release

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#year, genre
movieinfo = pd.read_csv('../data/final_movies_list.csv', delimiter="\t")
years = pd.unique(movieinfo['Year'])

# %%
print(np.sort(years))
# Out:
# [1915 1928 1931 1932 1933 1934 1936 1939 1940 1941 1942 1944 1946 1948
#  1950 1951 1952 1953 1954 1955 1956 1957 1958 1960 1961 1962 1963 1964
#  1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978
#  1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992
#  1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020
#  2021 2022]

# %%
# plt.figure(figsize=(17, 3))
sns.set(font_scale=1)
# sns.set(rc={'figure.figsize':(17,3)})
sns.catplot(x="Year", kind="count", palette="RdYlGn", data=movieinfo, height=15.27, aspect=11.7/5.27)

# %%
yearly = movieinfo['Year'].value_counts()
yearly.head(10)
# Out:
# 2009    63
# 2011    54
# 1999    49
# 1997    47
# 2000    44
# 2008    42
# 2010    40
# 1998    40
# 2001    39
# 2012    37
# Name: Year, dtype: int64

# %%
y = movieinfo['Year']

# %%
for i, j in enumerate(y):
    if j < 1930:
        y[i] = 1930
    elif j < 1945:
        y[i] = 1945
    elif j < 1960:
        y[i] = 1960
    elif j < 1975:
        y[i] = 1975
    elif j < 1990:
        y[i] = 1990
    elif j < 2005:
        y[i] = 2005
    elif j < 2020:
        y[i] = 2020
    elif j < 2022:
        y[i] = 2022
print(y)
# Out:
# 0       2005
# 1       2020
# 2       2020
# 3       2005
# 4       2020
#         ...
# 1132    2005
# 1133    2020
# 1134    2020
# 1135    2020
# 1136    2020
# Name: Year, Length: 1137, dtype: int64
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i, j in enumerate(y):
    if j == 1930:
        y[i] = '1915-30'
    elif j == 1945:
        y[i] = '1930-45'
    elif j == 1960:
        y[i] = '1945-60'
    elif int(j) == 1975:
        y[i] = '1960-75'
    elif int(j) == 1990:
        y[i] = '1975-90'
    elif int(j) == 2005:
        y[i] = '1990-2005'
    elif int(j) == 2020:
        y[i] = '2005-20'
    elif j == 2022:
        y[i] = '2020-22'
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
print(y)
# Out:
# 0       1990-2005
# 1         2005-20
# 2         2005-20
# 3       1990-2005
# 4         2005-20
#           ...
# 1132    1990-2005
# 1133      2005-20
# 1134      2005-20
# 1135      2005-20
# 1136      2005-20
# Name: Year, Length: 1137, dtype: object

# %%
yearly3 = pd.DataFrame(y, index=None, columns = ['Year'])
yearly3 = yearly3.sort_values(by = ['Year'])
yearly3.head(10)
# Out:
#          Year
# 397   1915-30
# 789   1915-30
# 1008  1930-45
# 340   1930-45
# 564   1930-45
# 563   1930-45
# 1118  1930-45
# 98    1930-45
# 811   1930-45
# 251   1930-45

# %%
# ranged = pd.DataFrame(yearly3['Year'].value_counts())
# ranged

# %%
sns.set(font_scale=4)
sns.catplot(x="Year", kind="count", palette="RdYlGn", data=yearly3, height=15.27, aspect=11.7/5.27)

# %% [markdown]
# ## 2. By genre

# %%
genre = pd.DataFrame(movieinfo['Genre'])

# %%
genre.head(10)
# Out:
#                                 Genre
# 0               ['Comedy', 'Romance']
# 1                          ['Comedy']
# 2                           ['Drama']
# 3     ['Drama', 'Sci-Fi', 'Thriller']
# 4                           ['Drama']
# 5  ['Adventure', 'Drama', 'Thriller']
# 6              ['Adventure', 'Drama']
# 7     ['Action', 'Crime', 'Thriller']
# 8      ['Comedy', 'Drama', 'Romance']
# 9                           ['Drama']

# %%
unique_genre = []
for ind in genre.index:
    g = genre['Genre'][ind]
    g = g.replace('[', "").replace(']', "").replace('\'', "")
    g = g.split(", ")
    for i in g:
        if i not in unique_genre:
            unique_genre.append(i)

# %%
print(unique_genre)
# Out:
# ['Comedy', 'Romance', 'Drama', 'Sci-Fi', 'Thriller', 'Adventure', 'Action', 'Crime', 'Horror', 'Mystery', 'Animation', 'Fantasy', 'Family', 'Musical', 'Western', 'War', 'Biography', 'Music', 'Film-Noir', 'History', 'Short', 'Sport', 'Action.Thriller', 'Horror.Mystery']

# %%
count = []
for i, j in enumerate(unique_genre):
    temp = [j, 0]
    count.append(temp)
    
count = np.asarray(count)
for ind in genre.index:
    g = genre['Genre'][ind]
    g = g.replace('[', "").replace(']', "").replace('\'', "")
    g = g.split(", ")
    for i in g:
        index = np.where(count[:, 0] == i)
        count[index[0][0]][1] = int(count[index[0][0]][1]) + 1

# %%
print(count)
# Out:
# [['Comedy' '370']
#  ['Romance' '195']
#  ['Drama' '620']
#  ['Sci-Fi' '166']
#  ['Thriller' '380']
#  ['Adventure' '184']
#  ['Action' '307']
#  ['Crime' '216']
#  ['Horror' '154']
#  ['Mystery' '111']
#  ['Animation' '42']
#  ['Fantasy' '116']
#  ['Family' '42']
#  ['Musical' '25']
#  ['Western' '15']
#  ['War' '28']
#  ['Biography' '3']
#  ['Music' '5']
#  ['Film-Noir' '4']
#  ['History' '3']
#  ['Short' '3']
#  ['Sport' '2']
#  ['Action.Thriller' '1']
#  ['Horror.Mystery' '1']]

# %%
bygenre = pd.DataFrame(count, columns=['Genre', 'Count'])
bygenre['Count'] = bygenre['Count'].astype(int)

# %%
bygenre
# Out:
#               Genre  Count
# 0            Comedy    370
# 1           Romance    195
# 2             Drama    620
# 3            Sci-Fi    166
# 4          Thriller    380
# 5         Adventure    184
# 6            Action    307
# 7             Crime    216
# 8            Horror    154
# 9           Mystery    111
# 10        Animation     42
# 11          Fantasy    116
# 12           Family     42
# 13          Musical     25
# 14          Western     15
# 15              War     28
# 16        Biography      3
# 17            Music      5
# 18        Film-Noir      4
# 19          History      3
# 20            Short      3
# 21            Sport      2
# 22  Action.Thriller      1
# 23   Horror.Mystery      1

# %%
sns.set(font_scale=2)
sns.catplot(x="Genre", y="Count", kind = "bar", palette="RdYlGn", data=bygenre, height=15.27, aspect=11.7/5.27)
